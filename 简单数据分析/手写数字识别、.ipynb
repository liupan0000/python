# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

#不能解决回归问题
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

from sklearn.datasets import load_digits

# %%
train,target=load_digits(return_X_y=True)

# %%
lr = LogisticRegression(C=0.1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(train,target,test_size=0.2,
                                               random_state=10)

# %%
lr.fit(X_train,y_train)
#分类模型指标评价，使用score
lr.score(X_test,y_test)
# Out:
# 0.9638888888888889

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
knn.score(X_test,y_test)
# Out:
# 0.9861111111111112

# %%
y1 = lr.predict(X_test)
y2 = knn.predict(X_test)
y_test
# Out:
# array([5, 2, 5, 4, 8, 2, 4, 3, 3, 0, 8, 7, 0, 1, 8, 6, 9, 7, 9, 7, 1, 8,
#        6, 7, 8, 8, 5, 3, 5, 9, 3, 3, 7, 3, 4, 1, 9, 2, 5, 4, 2, 1, 0, 9,
#        2, 3, 6, 1, 9, 4, 4, 9, 8, 4, 8, 5, 9, 7, 8, 0, 4, 5, 8, 4, 7, 9,
#        0, 7, 1, 3, 9, 3, 3, 8, 0, 7, 3, 6, 5, 2, 0, 8, 8, 0, 1, 1, 2, 8,
#        8, 8, 2, 6, 3, 4, 7, 9, 8, 2, 9, 2, 5, 0, 8, 0, 4, 8, 8, 0, 6, 7,
#        3, 3, 9, 1, 5, 4, 6, 0, 8, 8, 1, 1, 7, 9, 9, 5, 2, 3, 3, 9, 7, 6,
#        2, 5, 4, 3, 3, 7, 6, 7, 2, 7, 4, 9, 5, 1, 9, 4, 6, 1, 1, 1, 4, 0,
#        4, 9, 1, 2, 3, 5, 0, 3, 4, 1, 5, 4, 9, 3, 5, 6, 4, 0, 8, 6, 7, 0,
#        9, 9, 4, 7, 3, 5, 2, 0, 6, 7, 5, 3, 9, 7, 1, 3, 2, 8, 3, 3, 1, 7,
#        1, 1, 1, 7, 1, 6, 7, 6, 9, 5, 2, 3, 5, 2, 9, 5, 4, 8, 2, 9, 1, 5,
#        0, 2, 3, 9, 0, 2, 0, 2, 1, 0, 5, 0, 6, 4, 2, 1, 9, 0, 9, 0, 6, 9,
#        4, 4, 9, 7, 5, 6, 1, 8, 7, 0, 8, 6, 2, 0, 1, 2, 3, 8, 4, 4, 3, 5,
#        7, 9, 7, 2, 0, 2, 0, 9, 2, 8, 6, 3, 6, 0, 6, 6, 6, 7, 1, 6, 1, 7,
# ...

# %%
#展示逻辑斯蒂回归和knn
#绘制图片

plt.figure(figsize=(12,16))
for i in range(100):
    ax = plt.subplot(10,10,i+1)
    title ="T:{},L:{},K:{}".format(y_test[i],y1[i],y2[i]) 
    ax.set_title(title)
    img_data = X_test[i]
    ax.imshow(img_data.reshape(8,8),cmap='binary')

# %%
# %timeit knn.fit(X_train,y_train)
# Out:
# 3.26 ms ± 50.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit knn.predict(X_test)
# Out:
# 55.3 ms ± 675 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit lr.fit(X_train,y_train)
# Out:
# 107 ms ± 1.19 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit lr.predict(X_test)
# Out:
# 75 µs ± 431 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
#logistic回归，计算精度偏低，训练耗时高于knn，测试时间很短
